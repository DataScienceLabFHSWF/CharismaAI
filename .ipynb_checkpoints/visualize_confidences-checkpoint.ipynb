# %%
import pandas as pd
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
files_AI = glob('test_speeches/predictions/onestep/confidences/*.xlsx')
files_test = glob('test_speeches/test/*.xlsx')

# %%
def compare(file1, file2):
    #print(file2[14:-5])
    df1 = pd.read_excel(file1, index_col=0).drop(columns='label').dropna(subset='sentence')
    print(df1.columns)
    print(df1.shape)
    df1 = df1.fillna(0)

    df2 =pd.read_excel(file2,skiprows=6,header=0).drop(columns=
                                                       'Unnamed: 0').rename(columns=
                                                                            {'Sentence':'sentence'}).dropna(subset=
                                                                                                            'sentence')

    print(df2.shape)
    df2.index = df2.index.fillna(0)
    
    df2 = df2.fillna(0)

    # Check if shapes are the same
    if df1.shape != df2.shape:
        print("Sheets have different shapes. They cannot be compared.")
    else:
        diff_df = df1.drop(columns='sentence').compare(df2.drop(columns='sentence').round(0).astype(int),
                                                       result_names=('Coding AI', 'Coding Human'),
                                                       keep_shape=True, keep_equal=True)#.round(0).astype(int)
        #print(diff_df.columns)#.get_level_values(0))
        for col in diff_df.columns.get_level_values(0):
            diff_df[col, "Final coding"] = None
            diff_df[' sentence'] = df1['sentence']
        diff_excel_path = 'differences/confidences/'+file2[14:-5]+'.xlsx'   
        diff_df = diff_df.reindex(sorted(diff_df.columns), axis=1)
        diff_df.reindex(sorted(diff_df.columns), axis=1).to_excel(diff_excel_path)
        print(f"Differences saved in '{diff_excel_path}'.")

# %%
files = tuple(zip(files_AI,files_test))
for f in files:
    compare(*f)
# Out:
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (29, 10)
# (29, 10)
# Differences saved in 'differences/confidences/test\Speech_10.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (9, 10)
# (9, 10)
# Differences saved in 'differences/confidences/test\Speech_1_Obama_.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (16, 10)
# (16, 10)
# Differences saved in 'differences/confidences/test\Speech_2_Maggie_Thatcher.xlsx'.
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (193, 10)
# (193, 10)
# Differences saved in 'differences/confidences/test\Speech_3_Testspeech.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (14, 10)
# (14, 10)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# Differences saved in 'differences/confidences/test\Speech_4.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (54, 10)
# (54, 10)
# Differences saved in 'differences/confidences/test\Speech_5.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (39, 10)
# (39, 10)
# Differences saved in 'differences/confidences/test\Speech_6.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (29, 10)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)
# (29, 10)
# Differences saved in 'differences/confidences/test\Speech_7.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (29, 10)
# (29, 10)
# Differences saved in 'differences/confidences/test\Speech_8.xlsx'.
# Index(['sentence', 'Metaphor/Simile', 'Rhetorical questions',
#        'Stories / anecdotes', 'Contrasts', 'Lists / Repetition ',
#        'Moral conviction', 'Sentiment of the collective',
#        'Ambitious goals / Setting high expectations', 'Confidence in goals'],
#       dtype='object')
# (29, 10)
# (29, 10)
# Differences saved in 'differences/confidences/test\Speech_9.xlsx'.
# C:\Users\felix\AppData\Local\Temp\ipykernel_13152\242311358.py:17: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df2.fillna(0)

# %%
diff_dfs = [pd.read_excel(file,header=(0,1), index_col=0) for file in glob('differences/confidences/test/*.xlsx')]
diff_df = pd.concat(diff_dfs)

# %%
diff_df['Confidence in goals']
# Out:
#        Coding AI  Coding Human  Final coding
# 1   1.148874e-06             0           NaN
# 2   1.146630e-06             0           NaN
# 3   1.004853e-06             0           NaN
# 4   1.053488e-06             0           NaN
# 5   1.034595e-06             0           NaN
# ..           ...           ...           ...
# 25  1.114819e-06             0           NaN
# 26  1.076087e-06             0           NaN
# 27  9.793814e-07             0           NaN
# 28  1.159378e-06             0           NaN
# 29  1.780360e-05             0           NaN
#
# [441 rows x 3 columns]

# %%
for tactic in diff_df.columns.get_level_values(0).unique()[1:]:
    print(tactic)
    plt.figure()
    sns.histplot(data=diff_df[tactic], x='Coding AI', hue='Coding Human',element="step", binwidth=0.05)
    plt.semilogy()
    plt.show()
    plt.clf()
# Out:
# Ambitious goals / Setting high expectations
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Confidence in goals
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Contrasts
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Lists / Repetition
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Metaphor/Simile
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Moral conviction
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Rhetorical questions
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Sentiment of the collective
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Stories / anecdotes
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\felix\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
